# %% [markdown]
# ## Equity Data

# %%
import pandas as pd

# Show all rows and columns (no truncation)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 0)
pd.set_option("display.max_colwidth", None)

# %%
import pandas as pd

# Load NSE equity symbols
url = "https://public.fyers.in/sym_details/NSE_CM.csv"
df = pd.read_csv(url)

# Display first few
print(df.head())
print(df.shape)
# Out:
#        10100000001     GOLDSTAR POWER LIMITED  0  11250  0.05  INE405Y01021  \
# 0    1010000000100  AMARA RAJA ENERGY MOB LTD  0      1  0.05  INE885A01032
# 1   10100000001000          SDL MH 6.56% 2032  5    100  0.01  IN2220200306
# 2   10100000001001    SEC RED NCD 9.40% SR. V  2      1  0.01  INE721A07NX5
# 3   10100000001004          SDL AP 6.79% 2034  5    100  0.01  IN1020200466
# 4  101000000010046        GOI LOAN 7.57% 2033  6      1  0.01  IN0020190065
#
#    0915-1530|1815-1915:  2025-10-17 Unnamed: 8   NSE:GOLDSTAR-SM  10  10.1  \
# 0  0915-1530|1815-1915:  2025-10-17        NaN      NSE:ARE&M-EQ  10    10
# 1  0915-1530|1815-1915:  2025-10-17        NaN    NSE:656MH32-SG  10    10
# 2  0915-1530|1815-1915:  2025-10-17        NaN    NSE:94SFL28-YL  10    10
# 3  0915-1530|1815-1915:  2025-10-17        NaN    NSE:679AP34-SG  10    10
# 4  0915-1530|1815-1915:  2025-10-17        NaN  NSE:757GS2033-GS  10    10
#
#        1   GOLDSTAR    1.1  -1.0  XX    10100000001.1  None  0.1  0.0
# 0    100      ARE&M    100  -1.0  XX    1010000000100   NaN    1  3.2
# 1   1000    656MH32   1000  -1.0  XX   10100000001000   NaN    0  0.0
# 2   1001    94SFL28   1001  -1.0  XX   10100000001001   NaN    0  0.0
# 3   1004    679AP34   1004  -1.0  XX   10100000001004   NaN    0  0.0
# 4  10046  757GS2033  10046  -1.0  XX  101000000010046   NaN    0  0.0
# (8710, 21)

# %%
len(df.iloc[:,1].unique())
# Out:
# 8196

# %%
import pandas as pd

# Load NSE symbols
url = "https://public.fyers.in/sym_details/NSE_CM.csv"
df = pd.read_csv(url)

# Assuming FYERS symbol is in column 9
df.columns = [f"col{i}" for i in range(df.shape[1])]  # temporary column names
symbols = df["col9"].dropna()  # get FYERS symbols

# -------------------------------
# 1️⃣ Count of unique types (after last '-')
types = symbols.str.split('-').str[-1]
type_counts = types.value_counts()
print("Counts of symbol types (descending):")
print(type_counts)
# Out:
# Counts of symbol types (descending):
# col9
# SG    3732
# EQ    2300
# N0     617
# SM     427
# MF     204
#       ...
# Y6       1
# Y5       1
# Y4       1
# ZZ       1
# YN       1
# Name: count, Length: 149, dtype: int64

# %%
import pandas as pd

# Load NSE symbols
url = "https://public.fyers.in/sym_details/NSE_CM.csv"
df = pd.read_csv(url)

# Assign temporary column names for clarity
df.columns = [f"col{i}" for i in range(df.shape[1])]
df_subset = df.iloc[:, [1, 9]]  # company name and FYERS symbol
df_subset.columns = ["Company", "FyersSymbol"]

# Keep only EQ, INDEX, and MF symbols
df_filtered = df_subset[df_subset["FyersSymbol"].str.endswith(("EQ", "INDEX", "MF"))]

# Reset index
df_filtered = df_filtered.reset_index(drop=True)

# Save to CSV
# df_filtered.to_csv("symbols_filtered.csv", index=False)
print(f"Filtered symbols saved: {df_filtered.shape[0]} entries")
# Out:
# Filtered symbols saved: 2624 entries

# %% [markdown]
# ## Derivative Data

# %%
from fyers_apiv3 import fyersModel
from config import CLIENT_ID, AUTH_CODE, REDIRECT_URI, RESPONSE_TYPE, STATE, SECRET_KEY, GRANT_TYPE

# --- Exchange auth_code for access_token ---
session = fyersModel.SessionModel(
    client_id=CLIENT_ID,
    secret_key=SECRET_KEY,
    redirect_uri=REDIRECT_URI,
    response_type=RESPONSE_TYPE,
    state=STATE,
    grant_type=GRANT_TYPE
)

session.set_token(AUTH_CODE)
response = session.generate_token()

access_token = response.get("access_token")
print(access_token)
fyers = fyersModel.FyersModel(client_id=CLIENT_ID, token=access_token, is_async=False)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....I_9rsxugiqlCwfxzr3fnunmOwwdNFkNLZL2dEQnjgGw

# %%
data = {"symbol":"NSE:TCS-EQ","strikecount":1}
response = fyers.optionchain(data=data)
# response['data']['optionsChain'][0]['symbol']
response['data']['expiryData']
# Out:
# [{'date': '28-10-2025', 'expiry': '1761645600'},
#  {'date': '25-11-2025', 'expiry': '1764064800'},
#  {'date': '30-12-2025', 'expiry': '1767088800'}]

# %%
data = {'symbol':"NSE:TCS-EQ", 'timestamp': "1761645600"}
response = fyers.optionchain(data=data)
response
# Out:
# {'code': 200,
#  'data': {'callOi': 21868350,
#   'expiryData': [{'date': '28-10-2025', 'expiry': '1761645600'},
#    {'date': '25-11-2025', 'expiry': '1764064800'},
#    {'date': '30-12-2025', 'expiry': '1767088800'}],
#   'indiavixData': {'ask': 0,
#    'bid': 0,
#    'description': 'INDIAVIX-INDEX',
#    'ex_symbol': 'INDIAVIX',
#    'exchange': 'NSE',
#    'fyToken': '101000000026017',
#    'ltp': 11.63,
#    'ltpch': 0.76,
#    'ltpchp': 6.99,
#    'option_type': '',
#    'strike_price': -1,
#    'symbol': 'NSE:INDIAVIX-INDEX'},
#   'optionsChain': [{'ask': 2962.2,
#     'bid': 0,
#     'description': 'TATA CONSULTANCY SERV LT',
#     'ex_symbol': 'TCS',
#     'exchange': 'NSE',
#     'fp': 2969.1,
#     'fpch': -12.9,
#     'fpchp': -0.43,
#     'fyToken': '101000000011536',
#     'ltp': 2962.2,
#     'ltpch': -8.5,
#     'ltpchp': -0.29,
#     'option_type': '',
#     'strike_price': -1,
#     'symbol': 'NSE:TCS-EQ'},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129583',
#     'ltp': 1214.15,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1760,
#     'symbol': 'NSE:TCS25OCT1760CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129584',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1760,
#     'symbol': 'NSE:TCS25OCT1760PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123335',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1800,
#     'symbol': 'NSE:TCS25OCT1800PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123334',
#     'ltp': 1174.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1800,
#     'symbol': 'NSE:TCS25OCT1800CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129586',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1840,
#     'symbol': 'NSE:TCS25OCT1840PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129585',
#     'ltp': 1134.3,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1840,
#     'symbol': 'NSE:TCS25OCT1840CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123336',
#     'ltp': 1094.4,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1880,
#     'symbol': 'NSE:TCS25OCT1880CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123337',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1880,
#     'symbol': 'NSE:TCS25OCT1880PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129587',
#     'ltp': 1054.45,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1920,
#     'symbol': 'NSE:TCS25OCT1920CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129588',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1920,
#     'symbol': 'NSE:TCS25OCT1920PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123338',
#     'ltp': 1014.55,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 1960,
#     'symbol': 'NSE:TCS25OCT1960CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123339',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 1960,
#     'symbol': 'NSE:TCS25OCT1960PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129590',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2000,
#     'symbol': 'NSE:TCS25OCT2000PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129589',
#     'ltp': 974.65,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2000,
#     'symbol': 'NSE:TCS25OCT2000CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123341',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2040,
#     'symbol': 'NSE:TCS25OCT2040PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123340',
#     'ltp': 934.7,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2040,
#     'symbol': 'NSE:TCS25OCT2040CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129592',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2080,
#     'symbol': 'NSE:TCS25OCT2080PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129591',
#     'ltp': 894.8,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2080,
#     'symbol': 'NSE:TCS25OCT2080CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123342',
#     'ltp': 854.85,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2120,
#     'symbol': 'NSE:TCS25OCT2120CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123345',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2120,
#     'symbol': 'NSE:TCS25OCT2120PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129594',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2160,
#     'symbol': 'NSE:TCS25OCT2160PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129593',
#     'ltp': 814.95,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2160,
#     'symbol': 'NSE:TCS25OCT2160CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102837734',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2180,
#     'symbol': 'NSE:TCS25OCT2180PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102837733',
#     'ltp': 795,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2180,
#     'symbol': 'NSE:TCS25OCT2180CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123346',
#     'ltp': 775,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2200,
#     'symbol': 'NSE:TCS25OCT2200CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123349',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2200,
#     'symbol': 'NSE:TCS25OCT2200PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102849042',
#     'ltp': 755.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2220,
#     'symbol': 'NSE:TCS25OCT2220CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102849043',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2220,
#     'symbol': 'NSE:TCS25OCT2220PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129595',
#     'ltp': 735.1,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2240,
#     'symbol': 'NSE:TCS25OCT2240CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129596',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2240,
#     'symbol': 'NSE:TCS25OCT2240PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102847954',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2260,
#     'symbol': 'NSE:TCS25OCT2260PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102847953',
#     'ltp': 715.15,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2260,
#     'symbol': 'NSE:TCS25OCT2260CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102836940',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2280,
#     'symbol': 'NSE:TCS25OCT2280PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102836939',
#     'ltp': 695.2,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2280,
#     'symbol': 'NSE:TCS25OCT2280CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102842319',
#     'ltp': 675.2,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2300,
#     'symbol': 'NSE:TCS25OCT2300CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102842320',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2300,
#     'symbol': 'NSE:TCS25OCT2300PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129597',
#     'ltp': 655.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2320,
#     'symbol': 'NSE:TCS25OCT2320CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129598',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2320,
#     'symbol': 'NSE:TCS25OCT2320PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841679',
#     'ltp': 635.3,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2340,
#     'symbol': 'NSE:TCS25OCT2340CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841680',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2340,
#     'symbol': 'NSE:TCS25OCT2340PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129611',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2360,
#     'symbol': 'NSE:TCS25OCT2360PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129610',
#     'ltp': 615.35,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2360,
#     'symbol': 'NSE:TCS25OCT2360CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123356',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2380,
#     'symbol': 'NSE:TCS25OCT2380PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123354',
#     'ltp': 595.35,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2380,
#     'symbol': 'NSE:TCS25OCT2380CE',
#     'volume': 0},
#    {'ask': 0.75,
#     'bid': 0.65,
#     'fyToken': '1011251028129613',
#     'ltp': 0.55,
#     'ltpch': 0.05,
#     'ltpchp': 10,
#     'oi': 64400,
#     'oich': 175,
#     'oichp': 0.27,
#     'option_type': 'PE',
#     'prev_oi': 64225,
#     'strike_price': 2400,
#     'symbol': 'NSE:TCS25OCT2400PE',
#     'volume': 4550},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129612',
#     'ltp': 575.4,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2400,
#     'symbol': 'NSE:TCS25OCT2400CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123358',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2420,
#     'symbol': 'NSE:TCS25OCT2420PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123357',
#     'ltp': 555.45,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2420,
#     'symbol': 'NSE:TCS25OCT2420CE',
#     'volume': 0},
#    {'ask': 544.9,
#     'bid': 524.25,
#     'fyToken': '1011251028129614',
#     'ltp': 636.35,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2440,
#     'symbol': 'NSE:TCS25OCT2440CE',
#     'volume': 0},
#    {'ask': 0.75,
#     'bid': 0.4,
#     'fyToken': '1011251028129615',
#     'ltp': 0.75,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 8050,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 8050,
#     'strike_price': 2440,
#     'symbol': 'NSE:TCS25OCT2440PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123360',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2460,
#     'symbol': 'NSE:TCS25OCT2460PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123359',
#     'ltp': 515.55,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2460,
#     'symbol': 'NSE:TCS25OCT2460CE',
#     'volume': 0},
#    {'ask': 505.05,
#     'bid': 483.05,
#     'fyToken': '1011251028129616',
#     'ltp': 502.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 350,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 350,
#     'strike_price': 2480,
#     'symbol': 'NSE:TCS25OCT2480CE',
#     'volume': 0},
#    {'ask': 0.75,
#     'bid': 0.5,
#     'fyToken': '1011251028129617',
#     'ltp': 0.6,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 51975,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 51975,
#     'strike_price': 2480,
#     'symbol': 'NSE:TCS25OCT2480PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123362',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2500,
#     'symbol': 'NSE:TCS25OCT2500PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123361',
#     'ltp': 475.6,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2500,
#     'symbol': 'NSE:TCS25OCT2500CE',
#     'volume': 0},
#    {'ask': 465.2,
#     'bid': 443,
#     'fyToken': '1011251028129618',
#     'ltp': 560.9,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2520,
#     'symbol': 'NSE:TCS25OCT2520CE',
#     'volume': 0},
#    {'ask': 0.65,
#     'bid': 0.55,
#     'fyToken': '1011251028129619',
#     'ltp': 0.6,
#     'ltpch': -0.25,
#     'ltpchp': -29.41,
#     'oi': 70350,
#     'oich': -1050,
#     'oichp': -1.47,
#     'option_type': 'PE',
#     'prev_oi': 71400,
#     'strike_price': 2520,
#     'symbol': 'NSE:TCS25OCT2520PE',
#     'volume': 25550},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123364',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2540,
#     'symbol': 'NSE:TCS25OCT2540PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123363',
#     'ltp': 435.7,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2540,
#     'symbol': 'NSE:TCS25OCT2540CE',
#     'volume': 0},
#    {'ask': 0.75,
#     'bid': 0.55,
#     'fyToken': '1011251028129621',
#     'ltp': 0.6,
#     'ltpch': -0.15,
#     'ltpchp': -20,
#     'oi': 89425,
#     'oich': -1225,
#     'oichp': -1.35,
#     'option_type': 'PE',
#     'prev_oi': 90650,
#     'strike_price': 2560,
#     'symbol': 'NSE:TCS25OCT2560PE',
#     'volume': 3150},
#    {'ask': 425.25,
#     'bid': 403.2,
#     'fyToken': '1011251028129620',
#     'ltp': 524,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2560,
#     'symbol': 'NSE:TCS25OCT2560CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123366',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2580,
#     'symbol': 'NSE:TCS25OCT2580PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123365',
#     'ltp': 395.8,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2580,
#     'symbol': 'NSE:TCS25OCT2580CE',
#     'volume': 0},
#    {'ask': 371.95,
#     'bid': 367.65,
#     'fyToken': '1011251028129622',
#     'ltp': 366.9,
#     'ltpch': -15.1,
#     'ltpchp': -3.95,
#     'oi': 96075,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 96075,
#     'strike_price': 2600,
#     'symbol': 'NSE:TCS25OCT2600CE',
#     'volume': 350},
#    {'ask': 0.9,
#     'bid': 0.85,
#     'fyToken': '1011251028129623',
#     'ltp': 0.9,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 452550,
#     'oich': -17500,
#     'oichp': -3.72,
#     'option_type': 'PE',
#     'prev_oi': 470050,
#     'strike_price': 2600,
#     'symbol': 'NSE:TCS25OCT2600PE',
#     'volume': 83300},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123367',
#     'ltp': 355.9,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2620,
#     'symbol': 'NSE:TCS25OCT2620CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123368',
#     'ltp': 0.1,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 2620,
#     'symbol': 'NSE:TCS25OCT2620PE',
#     'volume': 0},
#    {'ask': 1.3,
#     'bid': 0.6,
#     'fyToken': '1011251028129625',
#     'ltp': 0.9,
#     'ltpch': 0.05,
#     'ltpchp': 5.88,
#     'oi': 148400,
#     'oich': -1750,
#     'oichp': -1.17,
#     'option_type': 'PE',
#     'prev_oi': 150150,
#     'strike_price': 2640,
#     'symbol': 'NSE:TCS25OCT2640PE',
#     'volume': 13300},
#    {'ask': 345.55,
#     'bid': 323.9,
#     'fyToken': '1011251028129624',
#     'ltp': 267.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 175,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 175,
#     'strike_price': 2640,
#     'symbol': 'NSE:TCS25OCT2640CE',
#     'volume': 0},
#    {'ask': 325.75,
#     'bid': 304.75,
#     'fyToken': '1011251028123369',
#     'ltp': 467.4,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2660,
#     'symbol': 'NSE:TCS25OCT2660CE',
#     'volume': 0},
#    {'ask': 1.25,
#     'bid': 0.85,
#     'fyToken': '1011251028123370',
#     'ltp': 1.15,
#     'ltpch': 0.15,
#     'ltpchp': 15,
#     'oi': 99575,
#     'oich': -5425,
#     'oichp': -5.17,
#     'option_type': 'PE',
#     'prev_oi': 105000,
#     'strike_price': 2660,
#     'symbol': 'NSE:TCS25OCT2660PE',
#     'volume': 10150},
#    {'ask': 1.45,
#     'bid': 1.15,
#     'fyToken': '1011251028129627',
#     'ltp': 1.35,
#     'ltpch': 0.21,
#     'ltpchp': 18.42,
#     'oi': 142275,
#     'oich': -28350,
#     'oichp': -16.62,
#     'option_type': 'PE',
#     'prev_oi': 170625,
#     'strike_price': 2680,
#     'symbol': 'NSE:TCS25OCT2680PE',
#     'volume': 53200},
#    {'ask': 306.1,
#     'bid': 284.85,
#     'fyToken': '1011251028129626',
#     'ltp': 417.95,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 2680,
#     'symbol': 'NSE:TCS25OCT2680CE',
#     'volume': 0},
#    {'ask': 279.45,
#     'bid': 267.6,
#     'fyToken': '1011251028123371',
#     'ltp': 282.2,
#     'ltpch': -0.05,
#     'ltpchp': -0.02,
#     'oi': 13300,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 13300,
#     'strike_price': 2700,
#     'symbol': 'NSE:TCS25OCT2700CE',
#     'volume': 0},
#    {'ask': 1.6,
#     'bid': 1.45,
#     'fyToken': '1011251028123372',
#     'ltp': 1.5,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 504875,
#     'oich': -350,
#     'oichp': -0.07,
#     'option_type': 'PE',
#     'prev_oi': 505225,
#     'strike_price': 2700,
#     'symbol': 'NSE:TCS25OCT2700PE',
#     'volume': 228200},
#    {'ask': 2,
#     'bid': 1.95,
#     'fyToken': '1011251028129633',
#     'ltp': 1.95,
#     'ltpch': 0.1,
#     'ltpchp': 5.41,
#     'oi': 110075,
#     'oich': -2275,
#     'oichp': -2.02,
#     'option_type': 'PE',
#     'prev_oi': 112350,
#     'strike_price': 2720,
#     'symbol': 'NSE:TCS25OCT2720PE',
#     'volume': 131950},
#    {'ask': 259.5,
#     'bid': 244.75,
#     'fyToken': '1011251028129628',
#     'ltp': 313.15,
#     'ltpch': 0.01,
#     'ltpchp': 0,
#     'oi': 3150,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 3150,
#     'strike_price': 2720,
#     'symbol': 'NSE:TCS25OCT2720CE',
#     'volume': 0},
#    {'ask': 247.4,
#     'bid': 225.45,
#     'fyToken': '1011251028123373',
#     'ltp': 237.2,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 1750,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 1750,
#     'strike_price': 2740,
#     'symbol': 'NSE:TCS25OCT2740CE',
#     'volume': 0},
#    {'ask': 2.45,
#     'bid': 2.35,
#     'fyToken': '1011251028123374',
#     'ltp': 2.4,
#     'ltpch': 0.15,
#     'ltpchp': 6.67,
#     'oi': 188300,
#     'oich': 15925,
#     'oichp': 9.24,
#     'option_type': 'PE',
#     'prev_oi': 172375,
#     'strike_price': 2740,
#     'symbol': 'NSE:TCS25OCT2740PE',
#     'volume': 290500},
#    {'ask': 2.95,
#     'bid': 2.85,
#     'fyToken': '1011251028129637',
#     'ltp': 2.9,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 183400,
#     'oich': 10500,
#     'oichp': 6.07,
#     'option_type': 'PE',
#     'prev_oi': 172900,
#     'strike_price': 2760,
#     'symbol': 'NSE:TCS25OCT2760PE',
#     'volume': 167650},
#    {'ask': 219.3,
#     'bid': 205.45,
#     'fyToken': '1011251028129634',
#     'ltp': 218.5,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 10500,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 10500,
#     'strike_price': 2760,
#     'symbol': 'NSE:TCS25OCT2760CE',
#     'volume': 0},
#    {'ask': 210.45,
#     'bid': 186,
#     'fyToken': '1011251028123375',
#     'ltp': 182,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 1575,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 1575,
#     'strike_price': 2780,
#     'symbol': 'NSE:TCS25OCT2780CE',
#     'volume': 0},
#    {'ask': 3.6,
#     'bid': 3.5,
#     'fyToken': '1011251028123376',
#     'ltp': 3.5,
#     'ltpch': 0.1,
#     'ltpchp': 2.94,
#     'oi': 93275,
#     'oich': -8750,
#     'oichp': -8.58,
#     'option_type': 'PE',
#     'prev_oi': 102025,
#     'strike_price': 2780,
#     'symbol': 'NSE:TCS25OCT2780PE',
#     'volume': 248850},
#    {'ask': 4.55,
#     'bid': 4.4,
#     'fyToken': '1011251028129639',
#     'ltp': 4.45,
#     'ltpch': 0.36,
#     'ltpchp': 8.8,
#     'oi': 902475,
#     'oich': -20300,
#     'oichp': -2.2,
#     'option_type': 'PE',
#     'prev_oi': 922775,
#     'strike_price': 2800,
#     'symbol': 'NSE:TCS25OCT2800PE',
#     'volume': 1126475},
#    {'ask': 174.35,
#     'bid': 172.75,
#     'fyToken': '1011251028129638',
#     'ltp': 172.9,
#     'ltpch': -13.7,
#     'ltpchp': -7.34,
#     'oi': 173425,
#     'oich': -1400,
#     'oichp': -0.8,
#     'option_type': 'CE',
#     'prev_oi': 174825,
#     'strike_price': 2800,
#     'symbol': 'NSE:TCS25OCT2800CE',
#     'volume': 27825},
#    {'ask': 5.9,
#     'bid': 5.4,
#     'fyToken': '1011251028123378',
#     'ltp': 5.45,
#     'ltpch': 0.7,
#     'ltpchp': 14.74,
#     'oi': 111300,
#     'oich': 3675,
#     'oichp': 3.41,
#     'option_type': 'PE',
#     'prev_oi': 107625,
#     'strike_price': 2820,
#     'symbol': 'NSE:TCS25OCT2820PE',
#     'volume': 347025},
#    {'ask': 156.1,
#     'bid': 153.2,
#     'fyToken': '1011251028123377',
#     'ltp': 150.4,
#     'ltpch': -16.7,
#     'ltpchp': -9.99,
#     'oi': 19425,
#     'oich': -700,
#     'oichp': -3.48,
#     'option_type': 'CE',
#     'prev_oi': 20125,
#     'strike_price': 2820,
#     'symbol': 'NSE:TCS25OCT2820CE',
#     'volume': 5075},
#    {'ask': 136.45,
#     'bid': 134.9,
#     'fyToken': '1011251028129640',
#     'ltp': 135.75,
#     'ltpch': -5.4,
#     'ltpchp': -3.83,
#     'oi': 28525,
#     'oich': 4900,
#     'oichp': 20.74,
#     'option_type': 'CE',
#     'prev_oi': 23625,
#     'strike_price': 2840,
#     'symbol': 'NSE:TCS25OCT2840CE',
#     'volume': 19950},
#    {'ask': 6.85,
#     'bid': 6.75,
#     'fyToken': '1011251028129661',
#     'ltp': 6.75,
#     'ltpch': 0.55,
#     'ltpchp': 8.87,
#     'oi': 226800,
#     'oich': -26250,
#     'oichp': -10.37,
#     'option_type': 'PE',
#     'prev_oi': 253050,
#     'strike_price': 2840,
#     'symbol': 'NSE:TCS25OCT2840PE',
#     'volume': 532175},
#    {'ask': 8.85,
#     'bid': 8.6,
#     'fyToken': '1011251028123380',
#     'ltp': 8.7,
#     'ltpch': 0.7,
#     'ltpchp': 8.75,
#     'oi': 255325,
#     'oich': -12775,
#     'oichp': -4.77,
#     'option_type': 'PE',
#     'prev_oi': 268100,
#     'strike_price': 2860,
#     'symbol': 'NSE:TCS25OCT2860PE',
#     'volume': 507150},
#    {'ask': 118.55,
#     'bid': 117.1,
#     'fyToken': '1011251028123379',
#     'ltp': 120,
#     'ltpch': -9.9,
#     'ltpchp': -7.62,
#     'oi': 48650,
#     'oich': -175,
#     'oichp': -0.36,
#     'option_type': 'CE',
#     'prev_oi': 48825,
#     'strike_price': 2860,
#     'symbol': 'NSE:TCS25OCT2860CE',
#     'volume': 6475},
#    {'ask': 12.6,
#     'bid': 11.2,
#     'fyToken': '1011251028129663',
#     'ltp': 12,
#     'ltpch': 1.81,
#     'ltpchp': 17.76,
#     'oi': 287000,
#     'oich': -76825,
#     'oichp': -21.12,
#     'option_type': 'PE',
#     'prev_oi': 363825,
#     'strike_price': 2880,
#     'symbol': 'NSE:TCS25OCT2880PE',
#     'volume': 817950},
#    {'ask': 104.9,
#     'bid': 99.85,
#     'fyToken': '1011251028129662',
#     'ltp': 100.35,
#     'ltpch': -11.7,
#     'ltpchp': -10.44,
#     'oi': 105175,
#     'oich': 7525,
#     'oichp': 7.71,
#     'option_type': 'CE',
#     'prev_oi': 97650,
#     'strike_price': 2880,
#     'symbol': 'NSE:TCS25OCT2880CE',
#     'volume': 33950},
#    {'ask': 15,
#     'bid': 14.8,
#     'fyToken': '1011251028123382',
#     'ltp': 15,
#     'ltpch': 1.15,
#     'ltpchp': 8.3,
#     'oi': 1117375,
#     'oich': -63705,
#     'oichp': -5.39,
#     'option_type': 'PE',
#     'prev_oi': 1181080,
#     'strike_price': 2900,
#     'symbol': 'NSE:TCS25OCT2900PE',
#     'volume': 1416975},
#    {'ask': 84.25,
#     'bid': 83.4,
#     'fyToken': '1011251028123381',
#     'ltp': 84.3,
#     'ltpch': -11.7,
#     'ltpchp': -12.19,
#     'oi': 514850,
#     'oich': -17850,
#     'oichp': -3.35,
#     'option_type': 'CE',
#     'prev_oi': 532700,
#     'strike_price': 2900,
#     'symbol': 'NSE:TCS25OCT2900CE',
#     'volume': 506275},
#    {'ask': 19.8,
#     'bid': 19.55,
#     'fyToken': '1011251028129668',
#     'ltp': 19.6,
#     'ltpch': 1.46,
#     'ltpchp': 8.05,
#     'oi': 398825,
#     'oich': -6825,
#     'oichp': -1.68,
#     'option_type': 'PE',
#     'prev_oi': 405650,
#     'strike_price': 2920,
#     'symbol': 'NSE:TCS25OCT2920PE',
#     'volume': 908075},
#    {'ask': 68.85,
#     'bid': 67.75,
#     'fyToken': '1011251028129664',
#     'ltp': 68.15,
#     'ltpch': -12.19,
#     'ltpchp': -15.17,
#     'oi': 265125,
#     'oich': -700,
#     'oichp': -0.26,
#     'option_type': 'CE',
#     'prev_oi': 265825,
#     'strike_price': 2920,
#     'symbol': 'NSE:TCS25OCT2920CE',
#     'volume': 244125},
#    {'ask': 54.8,
#     'bid': 54.1,
#     'fyToken': '1011251028123383',
#     'ltp': 54.95,
#     'ltpch': -11.2,
#     'ltpchp': -16.93,
#     'oi': 224700,
#     'oich': -22050,
#     'oichp': -8.94,
#     'option_type': 'CE',
#     'prev_oi': 246750,
#     'strike_price': 2940,
#     'symbol': 'NSE:TCS25OCT2940CE',
#     'volume': 555800},
#    {'ask': 26,
#     'bid': 25.55,
#     'fyToken': '1011251028123386',
#     'ltp': 25.5,
#     'ltpch': 1.75,
#     'ltpchp': 7.37,
#     'oi': 380100,
#     'oich': 16975,
#     'oichp': 4.67,
#     'option_type': 'PE',
#     'prev_oi': 363125,
#     'strike_price': 2940,
#     'symbol': 'NSE:TCS25OCT2940PE',
#     'volume': 1075200},
#    {'ask': 33.95,
#     'bid': 33.5,
#     'fyToken': '1011251028129670',
#     'ltp': 33.5,
#     'ltpch': 2.45,
#     'ltpchp': 7.89,
#     'oi': 913150,
#     'oich': 16275,
#     'oichp': 1.81,
#     'option_type': 'PE',
#     'prev_oi': 896875,
#     'strike_price': 2960,
#     'symbol': 'NSE:TCS25OCT2960PE',
#     'volume': 1906625},
#    {'ask': 42.6,
#     'bid': 42.2,
#     'fyToken': '1011251028129669',
#     'ltp': 42.65,
#     'ltpch': -10.65,
#     'ltpchp': -19.98,
#     'oi': 844725,
#     'oich': 5950,
#     'oichp': 0.71,
#     'option_type': 'CE',
#     'prev_oi': 838775,
#     'strike_price': 2960,
#     'symbol': 'NSE:TCS25OCT2960CE',
#     'volume': 1708350},
#    {'ask': 33.4,
#     'bid': 33,
#     'fyToken': '1011251028123387',
#     'ltp': 33.35,
#     'ltpch': -9.7,
#     'ltpchp': -22.53,
#     'oi': 457975,
#     'oich': 81900,
#     'oichp': 21.78,
#     'option_type': 'CE',
#     'prev_oi': 376075,
#     'strike_price': 2980,
#     'symbol': 'NSE:TCS25OCT2980CE',
#     'volume': 2409050},
#    {'ask': 44.3,
#     'bid': 43.65,
#     'fyToken': '1011251028123460',
#     'ltp': 44.25,
#     'ltpch': 3.9,
#     'ltpchp': 9.67,
#     'oi': 550550,
#     'oich': 1575,
#     'oichp': 0.29,
#     'option_type': 'PE',
#     'prev_oi': 548975,
#     'strike_price': 2980,
#     'symbol': 'NSE:TCS25OCT2980PE',
#     'volume': 1250725},
#    {'ask': 56.9,
#     'bid': 56.25,
#     'fyToken': '1011251028129672',
#     'ltp': 56.9,
#     'ltpch': 5.25,
#     'ltpchp': 10.16,
#     'oi': 1234625,
#     'oich': -119175,
#     'oichp': -8.8,
#     'option_type': 'PE',
#     'prev_oi': 1353800,
#     'strike_price': 3000,
#     'symbol': 'NSE:TCS25OCT3000PE',
#     'volume': 1550850},
#    {'ask': 25.8,
#     'bid': 25.6,
#     'fyToken': '1011251028129671',
#     'ltp': 25.8,
#     'ltpch': -8.74,
#     'ltpchp': -25.3,
#     'oi': 2686950,
#     'oich': 37270,
#     'oichp': 1.41,
#     'option_type': 'CE',
#     'prev_oi': 2649680,
#     'strike_price': 3000,
#     'symbol': 'NSE:TCS25OCT3000CE',
#     'volume': 6578600},
#    {'ask': 71,
#     'bid': 70.15,
#     'fyToken': '1011251028123477',
#     'ltp': 70.55,
#     'ltpch': 6.05,
#     'ltpchp': 9.38,
#     'oi': 390775,
#     'oich': -17675,
#     'oichp': -4.33,
#     'option_type': 'PE',
#     'prev_oi': 408450,
#     'strike_price': 3020,
#     'symbol': 'NSE:TCS25OCT3020PE',
#     'volume': 263200},
#    {'ask': 19.8,
#     'bid': 19.7,
#     'fyToken': '1011251028123461',
#     'ltp': 19.75,
#     'ltpch': -7.3,
#     'ltpchp': -26.99,
#     'oi': 1043350,
#     'oich': 102550,
#     'oichp': 10.9,
#     'option_type': 'CE',
#     'prev_oi': 940800,
#     'strike_price': 3020,
#     'symbol': 'NSE:TCS25OCT3020CE',
#     'volume': 1523375},
#    {'ask': 15.15,
#     'bid': 15,
#     'fyToken': '1011251028129677',
#     'ltp': 15,
#     'ltpch': -6,
#     'ltpchp': -28.57,
#     'oi': 1305150,
#     'oich': -50400,
#     'oichp': -3.72,
#     'option_type': 'CE',
#     'prev_oi': 1355550,
#     'strike_price': 3040,
#     'symbol': 'NSE:TCS25OCT3040CE',
#     'volume': 1727075},
#    {'ask': 87.75,
#     'bid': 85.15,
#     'fyToken': '1011251028129678',
#     'ltp': 85.95,
#     'ltpch': 7.5,
#     'ltpchp': 9.56,
#     'oi': 474600,
#     'oich': -26250,
#     'oichp': -5.24,
#     'option_type': 'PE',
#     'prev_oi': 500850,
#     'strike_price': 3040,
#     'symbol': 'NSE:TCS25OCT3040PE',
#     'volume': 148750},
#    {'ask': 11.6,
#     'bid': 11.5,
#     'fyToken': '1011251028123478',
#     'ltp': 11.5,
#     'ltpch': -4.8,
#     'ltpchp': -29.45,
#     'oi': 1535975,
#     'oich': -44445,
#     'oichp': -2.81,
#     'option_type': 'CE',
#     'prev_oi': 1580420,
#     'strike_price': 3060,
#     'symbol': 'NSE:TCS25OCT3060CE',
#     'volume': 1672825},
#    {'ask': 103.7,
#     'bid': 101.45,
#     'fyToken': '1011251028123479',
#     'ltp': 102.35,
#     'ltpch': 8.85,
#     'ltpchp': 9.47,
#     'oi': 352450,
#     'oich': -19425,
#     'oichp': -5.22,
#     'option_type': 'PE',
#     'prev_oi': 371875,
#     'strike_price': 3060,
#     'symbol': 'NSE:TCS25OCT3060PE',
#     'volume': 45675},
#    {'ask': 119.85,
#     'bid': 118.6,
#     'fyToken': '1011251028129680',
#     'ltp': 118.3,
#     'ltpch': 8.75,
#     'ltpchp': 7.99,
#     'oi': 208775,
#     'oich': -3325,
#     'oichp': -1.57,
#     'option_type': 'PE',
#     'prev_oi': 212100,
#     'strike_price': 3080,
#     'symbol': 'NSE:TCS25OCT3080PE',
#     'volume': 16450},
#    {'ask': 9.05,
#     'bid': 8.8,
#     'fyToken': '1011251028129679',
#     'ltp': 9.15,
#     'ltpch': -3.3,
#     'ltpchp': -26.51,
#     'oi': 1257725,
#     'oich': -875,
#     'oichp': -0.07,
#     'option_type': 'CE',
#     'prev_oi': 1258600,
#     'strike_price': 3080,
#     'symbol': 'NSE:TCS25OCT3080CE',
#     'volume': 822325},
#    {'ask': 7.2,
#     'bid': 7.15,
#     'fyToken': '1011251028123480',
#     'ltp': 7.2,
#     'ltpch': -2.65,
#     'ltpchp': -26.9,
#     'oi': 3035550,
#     'oich': -198100,
#     'oichp': -6.13,
#     'option_type': 'CE',
#     'prev_oi': 3233650,
#     'strike_price': 3100,
#     'symbol': 'NSE:TCS25OCT3100CE',
#     'volume': 2448425},
#    {'ask': 138.25,
#     'bid': 137.1,
#     'fyToken': '1011251028123481',
#     'ltp': 137.1,
#     'ltpch': 10.4,
#     'ltpchp': 8.21,
#     'oi': 710325,
#     'oich': -21525,
#     'oichp': -2.94,
#     'option_type': 'PE',
#     'prev_oi': 731850,
#     'strike_price': 3100,
#     'symbol': 'NSE:TCS25OCT3100PE',
#     'volume': 137375},
#    {'ask': 156.75,
#     'bid': 155.6,
#     'fyToken': '1011251028129682',
#     'ltp': 153.6,
#     'ltpch': 10.8,
#     'ltpchp': 7.56,
#     'oi': 53200,
#     'oich': -3675,
#     'oichp': -6.46,
#     'option_type': 'PE',
#     'prev_oi': 56875,
#     'strike_price': 3120,
#     'symbol': 'NSE:TCS25OCT3120PE',
#     'volume': 11725},
#    {'ask': 5.8,
#     'bid': 5.65,
#     'fyToken': '1011251028129681',
#     'ltp': 5.8,
#     'ltpch': -1.85,
#     'ltpchp': -24.18,
#     'oi': 339850,
#     'oich': -30800,
#     'oichp': -8.31,
#     'option_type': 'CE',
#     'prev_oi': 370650,
#     'strike_price': 3120,
#     'symbol': 'NSE:TCS25OCT3120CE',
#     'volume': 651000},
#    {'ask': 175.65,
#     'bid': 174.45,
#     'fyToken': '1011251028123483',
#     'ltp': 174.25,
#     'ltpch': 9.25,
#     'ltpchp': 5.61,
#     'oi': 46550,
#     'oich': -700,
#     'oichp': -1.48,
#     'option_type': 'PE',
#     'prev_oi': 47250,
#     'strike_price': 3140,
#     'symbol': 'NSE:TCS25OCT3140PE',
#     'volume': 10150},
#    {'ask': 4.75,
#     'bid': 4.7,
#     'fyToken': '1011251028123482',
#     'ltp': 4.65,
#     'ltpch': -1.4,
#     'ltpchp': -23.14,
#     'oi': 418425,
#     'oich': -46900,
#     'oichp': -10.08,
#     'option_type': 'CE',
#     'prev_oi': 465325,
#     'strike_price': 3140,
#     'symbol': 'NSE:TCS25OCT3140CE',
#     'volume': 641375},
#    {'ask': 3.95,
#     'bid': 3.85,
#     'fyToken': '1011251028129683',
#     'ltp': 3.85,
#     'ltpch': -1.1,
#     'ltpchp': -22.22,
#     'oi': 450275,
#     'oich': -2100,
#     'oichp': -0.46,
#     'option_type': 'CE',
#     'prev_oi': 452375,
#     'strike_price': 3160,
#     'symbol': 'NSE:TCS25OCT3160CE',
#     'volume': 604625},
#    {'ask': 195.8,
#     'bid': 193.35,
#     'fyToken': '1011251028129684',
#     'ltp': 190.15,
#     'ltpch': 7.4,
#     'ltpchp': 4.05,
#     'oi': 61775,
#     'oich': -1750,
#     'oichp': -2.75,
#     'option_type': 'PE',
#     'prev_oi': 63525,
#     'strike_price': 3160,
#     'symbol': 'NSE:TCS25OCT3160PE',
#     'volume': 2975},
#    {'ask': 3.3,
#     'bid': 3.15,
#     'fyToken': '1011251028123484',
#     'ltp': 3.2,
#     'ltpch': -0.7,
#     'ltpchp': -17.95,
#     'oi': 282800,
#     'oich': -6475,
#     'oichp': -2.24,
#     'option_type': 'CE',
#     'prev_oi': 289275,
#     'strike_price': 3180,
#     'symbol': 'NSE:TCS25OCT3180CE',
#     'volume': 405825},
#    {'ask': 214.5,
#     'bid': 212.5,
#     'fyToken': '1011251028123485',
#     'ltp': 213,
#     'ltpch': 10.3,
#     'ltpchp': 5.08,
#     'oi': 27825,
#     'oich': -4725,
#     'oichp': -14.52,
#     'option_type': 'PE',
#     'prev_oi': 32550,
#     'strike_price': 3180,
#     'symbol': 'NSE:TCS25OCT3180PE',
#     'volume': 5425},
#    {'ask': 2.8,
#     'bid': 2.75,
#     'fyToken': '1011251028129687',
#     'ltp': 2.8,
#     'ltpch': -0.45,
#     'ltpchp': -13.85,
#     'oi': 2771825,
#     'oich': 6645,
#     'oichp': 0.24,
#     'option_type': 'CE',
#     'prev_oi': 2765180,
#     'strike_price': 3200,
#     'symbol': 'NSE:TCS25OCT3200CE',
#     'volume': 1479625},
#    {'ask': 233.7,
#     'bid': 231.65,
#     'fyToken': '1011251028129688',
#     'ltp': 232,
#     'ltpch': 11.35,
#     'ltpchp': 5.14,
#     'oi': 342650,
#     'oich': -16450,
#     'oichp': -4.58,
#     'option_type': 'PE',
#     'prev_oi': 359100,
#     'strike_price': 3200,
#     'symbol': 'NSE:TCS25OCT3200PE',
#     'volume': 38325},
#    {'ask': 2.35,
#     'bid': 2.2,
#     'fyToken': '1011251028123486',
#     'ltp': 2.25,
#     'ltpch': -0.45,
#     'ltpchp': -16.67,
#     'oi': 205100,
#     'oich': -22925,
#     'oichp': -10.05,
#     'option_type': 'CE',
#     'prev_oi': 228025,
#     'strike_price': 3220,
#     'symbol': 'NSE:TCS25OCT3220CE',
#     'volume': 173775},
#    {'ask': 259.7,
#     'bid': 243,
#     'fyToken': '1011251028123489',
#     'ltp': 242.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 15575,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 15575,
#     'strike_price': 3220,
#     'symbol': 'NSE:TCS25OCT3220PE',
#     'volume': 0},
#    {'ask': 1.95,
#     'bid': 1.85,
#     'fyToken': '1011251028129689',
#     'ltp': 1.9,
#     'ltpch': -0.39,
#     'ltpchp': -17.03,
#     'oi': 226450,
#     'oich': -18550,
#     'oichp': -7.57,
#     'option_type': 'CE',
#     'prev_oi': 245000,
#     'strike_price': 3240,
#     'symbol': 'NSE:TCS25OCT3240CE',
#     'volume': 219975},
#    {'ask': 274,
#     'bid': 266.55,
#     'fyToken': '1011251028129690',
#     'ltp': 260,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 34125,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 34125,
#     'strike_price': 3240,
#     'symbol': 'NSE:TCS25OCT3240PE',
#     'volume': 0},
#    {'ask': 1.65,
#     'bid': 1.55,
#     'fyToken': '1011251028123490',
#     'ltp': 1.55,
#     'ltpch': -0.4,
#     'ltpchp': -20.51,
#     'oi': 206850,
#     'oich': -18375,
#     'oichp': -8.16,
#     'option_type': 'CE',
#     'prev_oi': 225225,
#     'strike_price': 3260,
#     'symbol': 'NSE:TCS25OCT3260CE',
#     'volume': 96600},
#    {'ask': 298.9,
#     'bid': 282.15,
#     'fyToken': '1011251028123491',
#     'ltp': 213,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 10325,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 10325,
#     'strike_price': 3260,
#     'symbol': 'NSE:TCS25OCT3260PE',
#     'volume': 0},
#    {'ask': 313.55,
#     'bid': 309.05,
#     'fyToken': '1011251028129693',
#     'ltp': 287,
#     'ltpch': -15.85,
#     'ltpchp': -5.23,
#     'oi': 8050,
#     'oich': -350,
#     'oichp': -4.17,
#     'option_type': 'PE',
#     'prev_oi': 8400,
#     'strike_price': 3280,
#     'symbol': 'NSE:TCS25OCT3280PE',
#     'volume': 350},
#    {'ask': 1.5,
#     'bid': 1.4,
#     'fyToken': '1011251028129691',
#     'ltp': 1.5,
#     'ltpch': -0.15,
#     'ltpchp': -9.09,
#     'oi': 187950,
#     'oich': 17325,
#     'oichp': 10.15,
#     'option_type': 'CE',
#     'prev_oi': 170625,
#     'strike_price': 3280,
#     'symbol': 'NSE:TCS25OCT3280CE',
#     'volume': 115150},
#    {'ask': 332.25,
#     'bid': 328.85,
#     'fyToken': '1011251028123567',
#     'ltp': 332,
#     'ltpch': 14.3,
#     'ltpchp': 4.5,
#     'oi': 265300,
#     'oich': -3150,
#     'oichp': -1.17,
#     'option_type': 'PE',
#     'prev_oi': 268450,
#     'strike_price': 3300,
#     'symbol': 'NSE:TCS25OCT3300PE',
#     'volume': 5250},
#    {'ask': 1.3,
#     'bid': 1.2,
#     'fyToken': '1011251028123492',
#     'ltp': 1.3,
#     'ltpch': -0.1,
#     'ltpchp': -7.14,
#     'oi': 1130150,
#     'oich': -47600,
#     'oichp': -4.04,
#     'option_type': 'CE',
#     'prev_oi': 1177750,
#     'strike_price': 3300,
#     'symbol': 'NSE:TCS25OCT3300CE',
#     'volume': 394800},
#    {'ask': 358.2,
#     'bid': 334.95,
#     'fyToken': '1011251028129699',
#     'ltp': 300,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 5250,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 5250,
#     'strike_price': 3320,
#     'symbol': 'NSE:TCS25OCT3320PE',
#     'volume': 0},
#    {'ask': 1.05,
#     'bid': 0.95,
#     'fyToken': '1011251028129694',
#     'ltp': 0.95,
#     'ltpch': -0.1,
#     'ltpchp': -9.52,
#     'oi': 278075,
#     'oich': -11725,
#     'oichp': -4.05,
#     'option_type': 'CE',
#     'prev_oi': 289800,
#     'strike_price': 3320,
#     'symbol': 'NSE:TCS25OCT3320CE',
#     'volume': 70000},
#    {'ask': 373.5,
#     'bid': 366.85,
#     'fyToken': '1011251028123571',
#     'ltp': 371,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 6300,
#     'oich': 175,
#     'oichp': 2.86,
#     'option_type': 'PE',
#     'prev_oi': 6125,
#     'strike_price': 3340,
#     'symbol': 'NSE:TCS25OCT3340PE',
#     'volume': 175},
#    {'ask': 0.7,
#     'bid': 0.65,
#     'fyToken': '1011251028123570',
#     'ltp': 0.65,
#     'ltpch': -0.3,
#     'ltpchp': -31.58,
#     'oi': 363650,
#     'oich': -8575,
#     'oichp': -2.3,
#     'option_type': 'CE',
#     'prev_oi': 372225,
#     'strike_price': 3340,
#     'symbol': 'NSE:TCS25OCT3340CE',
#     'volume': 99400},
#    {'ask': 0.85,
#     'bid': 0.65,
#     'fyToken': '1011251028129700',
#     'ltp': 0.7,
#     'ltpch': -0.25,
#     'ltpchp': -26.32,
#     'oi': 146125,
#     'oich': -9100,
#     'oichp': -5.86,
#     'option_type': 'CE',
#     'prev_oi': 155225,
#     'strike_price': 3360,
#     'symbol': 'NSE:TCS25OCT3360CE',
#     'volume': 44100},
#    {'ask': 393.55,
#     'bid': 386.75,
#     'fyToken': '1011251028129701',
#     'ltp': 389.95,
#     'ltpch': 6.95,
#     'ltpchp': 1.81,
#     'oi': 2450,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 2450,
#     'strike_price': 3360,
#     'symbol': 'NSE:TCS25OCT3360PE',
#     'volume': 350},
#    {'ask': 0.8,
#     'bid': 0.7,
#     'fyToken': '1011251028123575',
#     'ltp': 0.7,
#     'ltpch': -0.25,
#     'ltpchp': -26.32,
#     'oi': 38500,
#     'oich': -4725,
#     'oichp': -10.93,
#     'option_type': 'CE',
#     'prev_oi': 43225,
#     'strike_price': 3380,
#     'symbol': 'NSE:TCS25OCT3380CE',
#     'volume': 12775},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123579',
#     'ltp': 402.8,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3380,
#     'symbol': 'NSE:TCS25OCT3380PE',
#     'volume': 0},
#    {'ask': 0.8,
#     'bid': 0.75,
#     'fyToken': '1011251028129702',
#     'ltp': 0.85,
#     'ltpch': -0.1,
#     'ltpchp': -10.53,
#     'oi': 632275,
#     'oich': -37975,
#     'oichp': -5.67,
#     'option_type': 'CE',
#     'prev_oi': 670250,
#     'strike_price': 3400,
#     'symbol': 'NSE:TCS25OCT3400CE',
#     'volume': 263375},
#    {'ask': 430.6,
#     'bid': 426.9,
#     'fyToken': '1011251028129703',
#     'ltp': 428.4,
#     'ltpch': 11.4,
#     'ltpchp': 2.73,
#     'oi': 304675,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 304675,
#     'strike_price': 3400,
#     'symbol': 'NSE:TCS25OCT3400PE',
#     'volume': 9275},
#    {'ask': 458.6,
#     'bid': 434.85,
#     'fyToken': '1011251028123583',
#     'ltp': 519.6,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 2450,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 2450,
#     'strike_price': 3420,
#     'symbol': 'NSE:TCS25OCT3420PE',
#     'volume': 0},
#    {'ask': 0.6,
#     'bid': 0.5,
#     'fyToken': '1011251028123580',
#     'ltp': 0.55,
#     'ltpch': -0.35,
#     'ltpchp': -38.89,
#     'oi': 46200,
#     'oich': -4025,
#     'oichp': -8.01,
#     'option_type': 'CE',
#     'prev_oi': 50225,
#     'strike_price': 3420,
#     'symbol': 'NSE:TCS25OCT3420CE',
#     'volume': 13125},
#    {'ask': 0.7,
#     'bid': 0.6,
#     'fyToken': '1011251028129704',
#     'ltp': 0.65,
#     'ltpch': -0.1,
#     'ltpchp': -13.33,
#     'oi': 49875,
#     'oich': -2625,
#     'oichp': -5,
#     'option_type': 'CE',
#     'prev_oi': 52500,
#     'strike_price': 3440,
#     'symbol': 'NSE:TCS25OCT3440CE',
#     'volume': 12600},
#    {'ask': 473,
#     'bid': 467.5,
#     'fyToken': '1011251028129708',
#     'ltp': 460,
#     'ltpch': 55,
#     'ltpchp': 13.58,
#     'oi': 5775,
#     'oich': -175,
#     'oichp': -2.94,
#     'option_type': 'PE',
#     'prev_oi': 5950,
#     'strike_price': 3440,
#     'symbol': 'NSE:TCS25OCT3440PE',
#     'volume': 175},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123584',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3460,
#     'symbol': 'NSE:TCS25OCT3460CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123594',
#     'ltp': 482.55,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3460,
#     'symbol': 'NSE:TCS25OCT3460PE',
#     'volume': 0},
#    {'ask': 518.7,
#     'bid': 498.4,
#     'fyToken': '1011251028129710',
#     'ltp': 595,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 15750,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 15750,
#     'strike_price': 3480,
#     'symbol': 'NSE:TCS25OCT3480PE',
#     'volume': 0},
#    {'ask': 0.55,
#     'bid': 0.45,
#     'fyToken': '1011251028129709',
#     'ltp': 0.5,
#     'ltpch': -0.2,
#     'ltpchp': -28.57,
#     'oi': 65275,
#     'oich': -9975,
#     'oichp': -13.26,
#     'option_type': 'CE',
#     'prev_oi': 75250,
#     'strike_price': 3480,
#     'symbol': 'NSE:TCS25OCT3480CE',
#     'volume': 11900},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123596',
#     'ltp': 522.5,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3500,
#     'symbol': 'NSE:TCS25OCT3500PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123595',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3500,
#     'symbol': 'NSE:TCS25OCT3500CE',
#     'volume': 0},
#    {'ask': 556.8,
#     'bid': 532.65,
#     'fyToken': '1011251028129712',
#     'ltp': 547.6,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 48650,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 48650,
#     'strike_price': 3520,
#     'symbol': 'NSE:TCS25OCT3520PE',
#     'volume': 0},
#    {'ask': 0.55,
#     'bid': 0.4,
#     'fyToken': '1011251028129711',
#     'ltp': 0.55,
#     'ltpch': -0.25,
#     'ltpchp': -31.25,
#     'oi': 104650,
#     'oich': -3500,
#     'oichp': -3.24,
#     'option_type': 'CE',
#     'prev_oi': 108150,
#     'strike_price': 3520,
#     'symbol': 'NSE:TCS25OCT3520CE',
#     'volume': 4375},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123597',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3540,
#     'symbol': 'NSE:TCS25OCT3540CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123604',
#     'ltp': 562.4,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3540,
#     'symbol': 'NSE:TCS25OCT3540PE',
#     'volume': 0},
#    {'ask': 0.65,
#     'bid': 0.45,
#     'fyToken': '1011251028129713',
#     'ltp': 0.65,
#     'ltpch': 0.1,
#     'ltpchp': 18.18,
#     'oi': 61250,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 61250,
#     'strike_price': 3560,
#     'symbol': 'NSE:TCS25OCT3560CE',
#     'volume': 175},
#    {'ask': 590.85,
#     'bid': 585.6,
#     'fyToken': '1011251028129714',
#     'ltp': 565,
#     'ltpch': 65,
#     'ltpchp': 13,
#     'oi': 25900,
#     'oich': -175,
#     'oichp': -0.67,
#     'option_type': 'PE',
#     'prev_oi': 26075,
#     'strike_price': 3560,
#     'symbol': 'NSE:TCS25OCT3560PE',
#     'volume': 175},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123605',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3580,
#     'symbol': 'NSE:TCS25OCT3580CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123606',
#     'ltp': 602.3,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3580,
#     'symbol': 'NSE:TCS25OCT3580PE',
#     'volume': 0},
#    {'ask': 630.25,
#     'bid': 626,
#     'fyToken': '1011251028129716',
#     'ltp': 630.65,
#     'ltpch': 8.65,
#     'ltpchp': 1.39,
#     'oi': 223125,
#     'oich': 175,
#     'oichp': 0.08,
#     'option_type': 'PE',
#     'prev_oi': 222950,
#     'strike_price': 3600,
#     'symbol': 'NSE:TCS25OCT3600PE',
#     'volume': 1225},
#    {'ask': 0.45,
#     'bid': 0.4,
#     'fyToken': '1011251028129715',
#     'ltp': 0.45,
#     'ltpch': 0.25,
#     'ltpchp': 125,
#     'oi': 149800,
#     'oich': -2100,
#     'oichp': -1.38,
#     'option_type': 'CE',
#     'prev_oi': 151900,
#     'strike_price': 3600,
#     'symbol': 'NSE:TCS25OCT3600CE',
#     'volume': 49875},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123608',
#     'ltp': 642.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3620,
#     'symbol': 'NSE:TCS25OCT3620PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123607',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3620,
#     'symbol': 'NSE:TCS25OCT3620CE',
#     'volume': 0},
#    {'ask': 670.65,
#     'bid': 661.4,
#     'fyToken': '1011251028129722',
#     'ltp': 664.85,
#     'ltpch': -10.15,
#     'ltpchp': -1.5,
#     'oi': 117775,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 117775,
#     'strike_price': 3640,
#     'symbol': 'NSE:TCS25OCT3640PE',
#     'volume': 1225},
#    {'ask': 0.65,
#     'bid': 0.3,
#     'fyToken': '1011251028129717',
#     'ltp': 0.2,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 38850,
#     'oich': -350,
#     'oichp': -0.89,
#     'option_type': 'CE',
#     'prev_oi': 39200,
#     'strike_price': 3640,
#     'symbol': 'NSE:TCS25OCT3640CE',
#     'volume': 350},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102839528',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3660,
#     'symbol': 'NSE:TCS25OCT3660CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102839529',
#     'ltp': 682.15,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3660,
#     'symbol': 'NSE:TCS25OCT3660PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129723',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3680,
#     'symbol': 'NSE:TCS25OCT3680CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129726',
#     'ltp': 702.15,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3680,
#     'symbol': 'NSE:TCS25OCT3680PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102839532',
#     'ltp': 722.1,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3700,
#     'symbol': 'NSE:TCS25OCT3700PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102839531',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3700,
#     'symbol': 'NSE:TCS25OCT3700CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129727',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3720,
#     'symbol': 'NSE:TCS25OCT3720CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129728',
#     'ltp': 742.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3720,
#     'symbol': 'NSE:TCS25OCT3720PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841141',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3740,
#     'symbol': 'NSE:TCS25OCT3740CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841142',
#     'ltp': 762,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3740,
#     'symbol': 'NSE:TCS25OCT3740PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129778',
#     'ltp': 781.95,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3760,
#     'symbol': 'NSE:TCS25OCT3760PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129729',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3760,
#     'symbol': 'NSE:TCS25OCT3760CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841759',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3780,
#     'symbol': 'NSE:TCS25OCT3780CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102841760',
#     'ltp': 801.95,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3780,
#     'symbol': 'NSE:TCS25OCT3780PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102838180',
#     'ltp': 821.9,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3800,
#     'symbol': 'NSE:TCS25OCT3800PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102838179',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3800,
#     'symbol': 'NSE:TCS25OCT3800CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129780',
#     'ltp': 861.8,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3840,
#     'symbol': 'NSE:TCS25OCT3840PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129779',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3840,
#     'symbol': 'NSE:TCS25OCT3840CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102847080',
#     'ltp': 901.75,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3880,
#     'symbol': 'NSE:TCS25OCT3880PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '101125102847075',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3880,
#     'symbol': 'NSE:TCS25OCT3880CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129782',
#     'ltp': 941.65,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3920,
#     'symbol': 'NSE:TCS25OCT3920PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129781',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3920,
#     'symbol': 'NSE:TCS25OCT3920CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123620',
#     'ltp': 981.6,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 3960,
#     'symbol': 'NSE:TCS25OCT3960PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123619',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 3960,
#     'symbol': 'NSE:TCS25OCT3960CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129783',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 4000,
#     'symbol': 'NSE:TCS25OCT4000CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129784',
#     'ltp': 1021.5,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 4000,
#     'symbol': 'NSE:TCS25OCT4000PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123621',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 4040,
#     'symbol': 'NSE:TCS25OCT4040CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123622',
#     'ltp': 1061.4,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 4040,
#     'symbol': 'NSE:TCS25OCT4040PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129785',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 4080,
#     'symbol': 'NSE:TCS25OCT4080CE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028129786',
#     'ltp': 1101.35,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 4080,
#     'symbol': 'NSE:TCS25OCT4080PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123624',
#     'ltp': 1141.25,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'PE',
#     'prev_oi': 0,
#     'strike_price': 4120,
#     'symbol': 'NSE:TCS25OCT4120PE',
#     'volume': 0},
#    {'ask': 0,
#     'bid': 0,
#     'fyToken': '1011251028123623',
#     'ltp': 0.05,
#     'ltpch': 0,
#     'ltpchp': 0,
#     'oi': 0,
#     'oich': 0,
#     'oichp': 0,
#     'option_type': 'CE',
#     'prev_oi': 0,
#     'strike_price': 4120,
#     'symbol': 'NSE:TCS25OCT4120CE',
#     'volume': 0}],
#   'putOi': 12344850},
#  'message': '',
#  's': 'ok'}

# %%
import pandas as pd
import time

df = pd.read_csv("D:\OneDrive - iitgn.ac.in\Desktop\Sem 5\Project CL399\HedgeOne\data_.csv")
d = []
i =0
for index, rows in df.iterrows():
    symbol = rows['symbol']
    data = {"symbol":symbol,"strikecount":1}
    time.sleep(0.1)

    try:
        response = fyers.optionchain(data=data)
        if response['code']==200:
            new_symbol = response['data']['optionsChain'][0]['symbol']
            d.append({
                "Company name":rows['name'],
                "Symbol":new_symbol,
                "Lot size":rows['lot_size']
            })
            i+=1
            print(f"{i} {rows['symbol']} ==> {new_symbol}")
        else:
            print("Error in fetching")
    except Exception as e:
        print(f"error got: {e}")

pd.DataFrame(d).to_csv("F&O_symbols.csv", index = False)
# Out:
# 1 NSE:360ONE25OCT1520CE ==> NSE:360ONE-EQ
# 2 NSE:ABB25OCT2800CE ==> NSE:ABB-EQ
# 3 NSE:ABCAPITAL25OCT355CE ==> NSE:ABCAPITAL-EQ
# 4 NSE:ADANIENSOL25OCT1130CE ==> NSE:ADANIENSOL-EQ
# 5 NSE:ADANIENT25OCT3260CE ==> NSE:ADANIENT-EQ
# 6 NSE:ADANIGREEN25OCT600CE ==> NSE:ADANIGREEN-EQ
# 7 NSE:ADANIPORTS25OCT800CE ==> NSE:ADANIPORTS-EQ
# 8 NSE:ALKEM25OCT3850CE ==> NSE:ALKEM-EQ
# 9 NSE:AMBER25OCT11800CE ==> NSE:AMBER-EQ
# 10 NSE:AMBUJACEM25OCT750CE ==> NSE:AMBUJACEM-EQ
# 11 NSE:ANGELONE25OCT2950CE ==> NSE:ANGELONE-EQ
# 12 NSE:APLAPOLLO25OCT2260CE ==> NSE:APLAPOLLO-EQ
# 13 NSE:APOLLOHOSP25OCT5850CE ==> NSE:APOLLOHOSP-EQ
# 14 NSE:ASHOKLEY25OCT80CE ==> NSE:ASHOKLEY-EQ
# 15 NSE:ASIANPAINT25OCT1240CE ==> NSE:ASIANPAINT-EQ
# 16 NSE:ASTRAL25OCT2000CE ==> NSE:ASTRAL-EQ
# 17 NSE:AUBANK25OCT950CE ==> NSE:AUBANK-EQ
# 18 NSE:AUROPHARMA25OCT1460CE ==> NSE:AUROPHARMA-EQ
# 19 NSE:AXISBANK25OCT1510CE ==> NSE:AXISBANK-EQ
# 20 NSE:BAJAJ-AUTO25OCT5900CE ==> NSE:BAJAJ-AUTO-EQ
# 21 NSE:BAJAJFINSV25OCT1320CE ==> NSE:BAJAJFINSV-EQ
# 22 NSE:BAJFINANCE25OCT1310CE ==> NSE:BAJFINANCE-EQ
# 23 NSE:BANDHANBNK25OCT105CE ==> NSE:BANDHANBNK-EQ
# 24 NSE:BANKBARODA25OCT337.5CE ==> NSE:BANKBARODA-EQ
# 25 NSE:BANKINDIA25OCT161CE ==> NSE:BANKINDIA-EQ
# 26 NSE:BANKNIFTY25OCT33000CE ==> NSE:NIFTYBANK-INDEX
# 27 NSE:BDL25OCT2020CE ==> NSE:BDL-EQ
# 28 NSE:BEL25OCT550CE ==> NSE:BEL-EQ
# 29 NSE:BHARATFORG25OCT640CE ==> NSE:BHARATFORG-EQ
# 30 NSE:BHARTIARTL25OCT1260CE ==> NSE:BHARTIARTL-EQ
# 31 NSE:BHEL25OCT307.5CE ==> NSE:BHEL-EQ
# 32 NSE:BIOCON25OCT245CE ==> NSE:BIOCON-EQ
# 33 NSE:BLUESTARCO25OCT2200CE ==> NSE:BLUESTARCO-EQ
# 34 NSE:BOSCHLTD25OCT57000CE ==> NSE:BOSCHLTD-EQ
# 35 NSE:BPCL25OCT230CE ==> NSE:BPCL-EQ
# 36 NSE:BRITANNIA25OCT7450CE ==> NSE:BRITANNIA-EQ
# 37 NSE:BSE25OCT1350CE ==> NSE:BSE-EQ
# 38 NSE:CAMS25OCT5050CE ==> NSE:CAMS-EQ
# 39 NSE:CANBK25OCT159CE ==> NSE:CANBK-EQ
# 40 NSE:CDSL25OCT1980CE ==> NSE:CDSL-EQ
# 41 NSE:CGPOWER25OCT890CE ==> NSE:CGPOWER-EQ
# 42 NSE:CHOLAFIN25OCT840CE ==> NSE:CHOLAFIN-EQ
# 43 NSE:CIPLA25OCT1870CE ==> NSE:CIPLA-EQ
# 44 NSE:COALINDIA25OCT297.5CE ==> NSE:COALINDIA-EQ
# 45 NSE:COFORGE25OCT1180CE ==> NSE:COFORGE-EQ
# 46 NSE:COLPAL25OCT1120CE ==> NSE:COLPAL-EQ
# 47 NSE:CONCOR25OCT695CE ==> NSE:CONCOR-EQ
# 48 NSE:CROMPTON25OCT450CE ==> NSE:CROMPTON-EQ
# 49 NSE:CUMMINSIND25OCT2000CE ==> NSE:CUMMINSIND-EQ
# 50 NSE:CYIENT25OCT1540CE ==> NSE:CYIENT-EQ
# 51 NSE:DABUR25OCT655CE ==> NSE:DABUR-EQ
# 52 NSE:DALBHARAT25OCT2980CE ==> NSE:DALBHARAT-EQ
# 53 NSE:DELHIVERY25OCT220CE ==> NSE:DELHIVERY-EQ
# 54 NSE:DIVISLAB25OCT4600CE ==> NSE:DIVISLAB-EQ
# 55 NSE:DIXON25OCT21750CE ==> NSE:DIXON-EQ
# 56 NSE:DLF25OCT360CE ==> NSE:DLF-EQ
# 57 NSE:DMART25OCT2300CE ==> NSE:DMART-EQ
# 58 NSE:DRREDDY25OCT1590CE ==> NSE:DRREDDY-EQ
# 59 NSE:EICHERMOT25OCT8000CE ==> NSE:EICHERMOT-EQ
# 60 NSE:ETERNAL25OCT190CE ==> NSE:ETERNAL-EQ
# 61 NSE:EXIDEIND25OCT510CE ==> NSE:EXIDEIND-EQ
# 62 NSE:FEDERALBNK25OCT135CE ==> NSE:FEDERALBNK-EQ
# 63 NSE:FINNIFTY25OCT29850CE ==> NSE:FINNIFTY-INDEX
# 64 NSE:FORTIS25OCT1230CE ==> NSE:FORTIS-EQ
# 65 NSE:GAIL25OCT115CE ==> NSE:GAIL-EQ
# 66 NSE:GLENMARK25OCT1000CE ==> NSE:GLENMARK-EQ
# 67 NSE:GMRAIRPORT25OCT48CE ==> NSE:GMRAIRPORT-EQ
# 68 NSE:GODREJCP25OCT560CE ==> NSE:GODREJCP-EQ
# 69 NSE:GODREJPROP25OCT1080CE ==> NSE:GODREJPROP-EQ
# 70 NSE:GRASIM25OCT4000CE ==> NSE:GRASIM-EQ
# 71 NSE:HAL25OCT2700CE ==> NSE:HAL-EQ
# 72 NSE:HAVELLS25OCT760CE ==> NSE:HAVELLS-EQ
# 73 NSE:HCLTECH25OCT1820CE ==> NSE:HCLTECH-EQ
# 74 NSE:HDFCAMC25OCT2900CE ==> NSE:HDFCAMC-EQ
# 75 NSE:HDFCBANK25OCT610CE ==> NSE:HDFCBANK-EQ
# 76 NSE:HDFCLIFE25OCT530CE ==> NSE:HDFCLIFE-EQ
# 77 NSE:HEROMOTOCO25OCT6850CE ==> NSE:HEROMOTOCO-EQ
# 78 NSE:HFCL25OCT38CE ==> NSE:HFCL-EQ
# 79 NSE:HINDALCO25OCT950CE ==> NSE:HINDALCO-EQ
# 80 NSE:HINDPETRO25OCT505CE ==> NSE:HINDPETRO-EQ
# 81 NSE:HINDUNILVR25OCT1320CE ==> NSE:HINDUNILVR-EQ
# 82 NSE:HINDZINC25OCT345CE ==> NSE:HINDZINC-EQ
# 83 NSE:HUDCO25OCT125CE ==> NSE:HUDCO-EQ
# 84 NSE:ICICIBANK25OCT700CE ==> NSE:ICICIBANK-EQ
# 85 NSE:ICICIGI25OCT1040CE ==> NSE:ICICIGI-EQ
# 86 NSE:ICICIPRULI25OCT330CE ==> NSE:ICICIPRULI-EQ
# 87 NSE:IDEA25OCT16CE ==> NSE:IDEA-EQ
# 88 NSE:IDFCFIRSTB25OCT94CE ==> NSE:IDFCFIRSTB-EQ
# 89 NSE:IEX25OCT187.5CE ==> NSE:IEX-EQ
# 90 NSE:IGL25OCT125CE ==> NSE:IGL-EQ
# 91 NSE:IIFL25OCT620CE ==> NSE:IIFL-EQ
# 92 NSE:INDHOTEL25OCT490CE ==> NSE:INDHOTEL-EQ
# 93 NSE:INDIANB25OCT910CE ==> NSE:INDIANB-EQ
# 94 NSE:INDIGO25OCT2900CE ==> NSE:INDIGO-EQ
# 95 NSE:INDUSINDBK25OCT540CE ==> NSE:INDUSINDBK-EQ
# 96 NSE:INDUSTOWER25OCT230CE ==> NSE:INDUSTOWER-EQ
# 97 NSE:INFY25OCT760CE ==> NSE:INFY-EQ
# 98 NSE:INOXWIND25OCT65CE ==> NSE:INOXWIND-EQ
# 99 NSE:IOC25OCT84CE ==> NSE:IOC-EQ
# 100 NSE:IRCTC25OCT390CE ==> NSE:IRCTC-EQ
# 101 NSE:IREDA25OCT85CE ==> NSE:IREDA-EQ
# 102 NSE:IRFC25OCT66CE ==> NSE:IRFC-EQ
# 103 NSE:ITC25OCT225CE ==> NSE:ITC-EQ
# 104 NSE:JINDALSTEL25OCT600CE ==> NSE:JINDALSTEL-EQ
# 105 NSE:JIOFIN25OCT200CE ==> NSE:JIOFIN-EQ
# 106 NSE:JSWENERGY25OCT320CE ==> NSE:JSWENERGY-EQ
# 107 NSE:JSWSTEEL25OCT680CE ==> NSE:JSWSTEEL-EQ
# 108 NSE:JUBLFOOD25OCT320CE ==> NSE:JUBLFOOD-EQ
# 109 NSE:KALYANKJIL25OCT360CE ==> NSE:KALYANKJIL-EQ
# 110 NSE:KAYNES25OCT4400CE ==> NSE:KAYNES-EQ
# 111 NSE:KEI25OCT2400CE ==> NSE:KEI-EQ
# 112 NSE:KFINTECH25OCT600CE ==> NSE:KFINTECH-EQ
# 113 NSE:KOTAKBANK25OCT1280CE ==> NSE:KOTAKBANK-EQ
# 114 NSE:KPITTECH25OCT640CE ==> NSE:KPITTECH-EQ
# 115 NSE:LAURUSLABS25OCT560CE ==> NSE:LAURUSLABS-EQ
# 116 NSE:LICHSGFIN25OCT360CE ==> NSE:LICHSGFIN-EQ
# 117 NSE:LICI25OCT480CE ==> NSE:LICI-EQ
# 118 NSE:LODHA25OCT640CE ==> NSE:LODHA-EQ
# 119 NSE:LT25OCT2400CE ==> NSE:LT-EQ
# 120 NSE:LTF25OCT295PE ==> NSE:LTF-EQ
# 121 NSE:LTIM25OCT3000CE ==> NSE:LTIM-EQ
# 122 NSE:LUPIN25OCT1080CE ==> NSE:LUPIN-EQ
# 123 NSE:M&M25OCT2100CE ==> NSE:M&M-EQ
# 124 NSE:MANAPPURAM25OCT150CE ==> NSE:MANAPPURAM-EQ
# 125 NSE:MANKIND25OCT1300CE ==> NSE:MANKIND-EQ
# 126 NSE:MARICO25OCT420CE ==> NSE:MARICO-EQ
# 127 NSE:MARUTI25OCT12500CE ==> NSE:MARUTI-EQ
# 128 NSE:MAXHEALTH25OCT640CE ==> NSE:MAXHEALTH-EQ
# 129 NSE:MAZDOCK25OCT1700CE ==> NSE:MAZDOCK-EQ
# 130 NSE:MCX25OCT4600CE ==> NSE:MCX-EQ
# 131 NSE:MFSL25OCT920CE ==> NSE:MFSL-EQ
# 132 NSE:MIDCPNIFTY25OCT10225CE ==> NSE:MIDCPNIFTY-INDEX
# 133 NSE:MOTHERSON25OCT87.5PE ==> NSE:MOTHERSON-EQ
# 134 NSE:MPHASIS25OCT1700CE ==> NSE:MPHASIS-EQ
# 135 NSE:MUTHOOTFIN25OCT2250CE ==> NSE:MUTHOOTFIN-EQ
# 136 NSE:NATIONALUM25OCT125CE ==> NSE:NATIONALUM-EQ
# 137 NSE:NAUKRI25OCT980CE ==> NSE:NAUKRI-EQ
# 138 NSE:NBCC25OCT97.5PE ==> NSE:NBCC-EQ
# 139 NSE:NCC25OCT135CE ==> NSE:NCC-EQ
# 140 NSE:NESTLEIND25OCT700CE ==> NSE:NESTLEIND-EQ
# 141 NSE:NHPC25OCT46CE ==> NSE:NHPC-EQ
# Error in fetching
# 142 NSE:NIFTYNXT5025OCT36000CE ==> NSE:NIFTYNXT50-INDEX
# 143 NSE:NMDC25OCT42CE ==> NSE:NMDC-EQ
# 144 NSE:NTPC25OCT190CE ==> NSE:NTPC-EQ
# 145 NSE:NUVAMA25OCT3800CE ==> NSE:NUVAMA-EQ
# 146 NSE:NYKAA25OCT177.5CE ==> NSE:NYKAA-EQ
# 147 NSE:OBEROIRLTY25OCT920CE ==> NSE:OBEROIRLTY-EQ
# 148 NSE:OFSS25OCT4600CE ==> NSE:OFSS-EQ
# 149 NSE:OIL25OCT250CE ==> NSE:OIL-EQ
# 150 NSE:ONGC25OCT165CE ==> NSE:ONGC-EQ
# 151 NSE:PAGEIND25OCT23000CE ==> NSE:PAGEIND-EQ
# 152 NSE:PATANJALI25OCT360CE ==> NSE:PATANJALI-EQ
# 153 NSE:PAYTM25OCT1020CE ==> NSE:PAYTM-EQ
# 154 NSE:PERSISTENT25OCT3000CE ==> NSE:PERSISTENT-EQ
# 155 NSE:PETRONET25OCT170CE ==> NSE:PETRONET-EQ
# 156 NSE:PFC25OCT270CE ==> NSE:PFC-EQ
# 157 NSE:PGEL25OCT300CE ==> NSE:PGEL-EQ
# 158 NSE:PHOENIXLTD25OCT840CE ==> NSE:PHOENIXLTD-EQ
# 159 NSE:PIDILITIND25OCT1020CE ==> NSE:PIDILITIND-EQ
# 160 NSE:PIIND25OCT1900CE ==> NSE:PIIND-EQ
# 161 NSE:PNB25OCT66CE ==> NSE:PNB-EQ
# 162 NSE:PNBHOUSING25OCT540CE ==> NSE:PNBHOUSING-EQ
# 163 NSE:POLICYBZR25OCT1450PE ==> NSE:POLICYBZR-EQ
# 164 NSE:POLYCAB25OCT4600CE ==> NSE:POLYCAB-EQ
# 165 NSE:POWERGRID25OCT170CE ==> NSE:POWERGRID-EQ
# 166 NSE:POWERINDIA25OCT10500CE ==> NSE:POWERINDIA-EQ
# 167 NSE:PPLPHARMA25OCT125CE ==> NSE:PPLPHARMA-EQ
# 168 NSE:PRESTIGE25OCT840CE ==> NSE:PRESTIGE-EQ
# 169 NSE:RBLBANK25OCT205CE ==> NSE:RBLBANK-EQ
# 170 NSE:RECLTD25OCT230CE ==> NSE:RECLTD-EQ
# 171 NSE:RELIANCE25OCT780CE ==> NSE:RELIANCE-EQ
# 172 NSE:RVNL25OCT190CE ==> NSE:RVNL-EQ
# 173 NSE:SAIL25OCT112.5PE ==> NSE:SAIL-EQ
# 174 NSE:SAMMAANCAP25OCT105CE ==> NSE:SAMMAANCAP-EQ
# 175 NSE:SBICARD25OCT460CE ==> NSE:SBICARD-EQ
# 176 NSE:SBILIFE25OCT960CE ==> NSE:SBILIFE-EQ
# 177 NSE:SBIN25OCT500CE ==> NSE:SBIN-EQ
# 178 NSE:SHREECEM25OCT16000CE ==> NSE:SHREECEM-EQ
# 179 NSE:SHRIRAMFIN25OCT340CE ==> NSE:SHRIRAMFIN-EQ
# 180 NSE:SIEMENS25OCT1600CE ==> NSE:SIEMENS-EQ
# 181 NSE:SOLARINDS25OCT7500CE ==> NSE:SOLARINDS-EQ
# 182 NSE:SONACOMS25OCT220CE ==> NSE:SONACOMS-EQ
# 183 NSE:SRF25OCT1700CE ==> NSE:SRF-EQ
# 184 NSE:SUNPHARMA25OCT920CE ==> NSE:SUNPHARMA-EQ
# 185 NSE:SUPREMEIND25OCT3300CE ==> NSE:SUPREMEIND-EQ
# 186 NSE:SUZLON25OCT34CE ==> NSE:SUZLON-EQ
# 187 NSE:SYNGENE25OCT340CE ==> NSE:SYNGENE-EQ
# 188 NSE:TATACONSUM25OCT660CE ==> NSE:TATACONSUM-EQ
# 189 NSE:TATAELXSI25OCT2800CE ==> NSE:TATAELXSI-EQ
# 190 NSE:TATAMOTORS25OCT510CE ==> NSE:TATAMOTORS-EQ
# 191 NSE:TATAPOWER25OCT210CE ==> NSE:TATAPOWER-EQ
# 192 NSE:TATASTEEL25OCT95CE ==> NSE:TATASTEEL-EQ
# 193 NSE:TATATECH25OCT490CE ==> NSE:TATATECH-EQ
# 194 NSE:TCS25OCT1640CE ==> NSE:TCS-EQ
# 195 NSE:TECHM25OCT760CE ==> NSE:TECHM-EQ
# 196 NSE:TIINDIA25OCT2050CE ==> NSE:TIINDIA-EQ
# 197 NSE:TITAGARH25OCT580CE ==> NSE:TITAGARH-EQ
# 198 NSE:TITAN25OCT3050PE ==> NSE:TITAN-EQ
# 199 NSE:TORNTPHARM25OCT2100CE ==> NSE:TORNTPHARM-EQ
# 200 NSE:TORNTPOWER25OCT680CE ==> NSE:TORNTPOWER-EQ
# 201 NSE:TRENT25OCT3000CE ==> NSE:TRENT-EQ
# 202 NSE:TVSMOTOR25OCT2450CE ==> NSE:TVSMOTOR-EQ
# 203 NSE:ULTRACEMCO25OCT7800CE ==> NSE:ULTRACEMCO-EQ
# 204 NSE:UNIONBANK25OCT102.5CE ==> NSE:UNIONBANK-EQ
# 205 NSE:UNITDSPR25OCT760CE ==> NSE:UNITDSPR-EQ
# 206 NSE:UNOMINDA25OCT1020CE ==> NSE:UNOMINDA-EQ
# 207 NSE:UPL25OCT420CE ==> NSE:UPL-EQ
# 208 NSE:VBL25OCT260CE ==> NSE:VBL-EQ
# 209 NSE:VEDL25OCT270CE ==> NSE:VEDL-EQ
# 210 NSE:VOLTAS25OCT760CE ==> NSE:VOLTAS-EQ
# 211 NSE:WIPRO25OCT135CE ==> NSE:WIPRO-EQ
# 212 NSE:YESBANK25OCT13CE ==> NSE:YESBANK-EQ
# 213 NSE:ZYDUSLIFE25OCT580CE ==> NSE:ZYDUSLIFE-EQ
